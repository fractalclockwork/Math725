# %% [markdown]
# # Math 725
#
# ### Brent A. Thorne <brentathorne@gmail.com>
#
# In class exercises, Week 3

# %%
# import libraries
import numpy as np
import sympy as sym
from sympy.matrices import Matrix
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex

# %% [markdown]
# ### FIXME
# Add notes from Sept 6

# %% [markdown]
# ### Useful resources
#
# https://mathoverflow.net/
#
# https://mathoverflow.net/search?q=Linear+Algebra+Done+Right

# %% [markdown]
# ### Axiom of Choice
#
# $V=U\oplus W$
#
# see also, https://en.wikipedia.org/wiki/Axiom_of_choice

# %%
from matplotlib_venn import venn3
diagram = venn3(subsets=[  set(['u']), set(['v']),set(['V','v','u']) ], set_labels=('u', 'v', 'V'))
display(Latex("This diagram also shows that u,v outside of V is Null and Zero Vector is in all sets. How cool is that?!"))

display(Latex("Happy Birds Taps..."))
# Out:
# This diagram also shows that u,v outside of V is Null and Zero Vector is in all sets. How cool is that?!
# Happy Birds Taps...

# %% [markdown]
# ### Ex 3.1 $\mathcal{P}_m(\Bbb{F})$ polynomial of degree at most $m$
#
# $3, 1+z, 1+...+z^4, z^m$
#
# $\beta= \underbrace{1, z, z^2,...,z^m}_{m+1}$
#
# $\alpha_1 1+\alpha_2 z+...+\alpha_{m+1}z^m=0$  *Note how Mathematicians use indexes starting at 1... strange.
#
# $\mathcal{P}(\Bbb{F}) - \underbrace{U\mathcal{P}_m(\Bbb{F})}_{m\geq 0} \implies$ infinitely many dimensions
#
# See also, Ex 2.16 LADR.

# %% [markdown]
# ### Theorem:
#
# If $U\subset V$ is finite dimensional, then $U$ is also finite dimensional.

# %%
import schemdraw # requires schemdraw==0.14, 0.15 isn't compatible with current matplotlib
from schemdraw import flow

display(Latex('If $U\subset V$ is finite dimensional, then $U$ is also finite dimensional.'))

with schemdraw.Drawing() as d:
    d += flow.Start().label('START')
    d += flow.Arrow().down(d.unit/3)
    
    d += (d0 := flow.Decision(w=3, h=2, E='YES',S='$u_1\in v_1$').label('u?={0}'))
    d += flow.Line().down(d.unit/4)
    d += (d1 := flow.Decision(w=4, h=2, E='YES', S='$\exists_{u_2}\in$ span$(v_1)$').label('span $(v_1) ?= u$'))
    d += flow.Line().down(d.unit/4)
    d += (d2 := flow.Decision(w=5, h=2, E='YES',S='$\exists_{u_3}\in$ span$(v_1,v_2)$').label('span $(v_1,v_2) ?= u$'))
    d += flow.Line().down(d.unit/4)
    d += (d3 := flow.Decision(w=3, h=2).label('...'))

    
    d += flow.Arrow().right(d.unit/2).at(d0.E)
    d += flow.Box(w=2, h=1.25).anchor('W').label('DONE')
    d += flow.Arrow().right(d.unit/2).at(d1.E)
    d += flow.Box(w=2, h=1.25).anchor('W').label('DONE')
    d += flow.Arrow().right(d.unit/2).at(d2.E)
    d += flow.Box(w=2, h=1.25).anchor('W').label('DONE')
display(Latex('$v_1,...,v_k$ is linearly independent, thus by L2.23 the process terminates.'))

#FIXME!!! Verify with Mathematician.
# Out:
# If $U\subset V$ is finite dimensional, then $U$ is also finite dimensional.
# $v_1,...,v_k$ is linearly independent, thus by L2.23 the process terminates.

# %%
with schemdraw.Drawing() as d:
    d += flow.Start().label('START')
    d += flow.Arrow().down(d.unit/3)
    d += (h := flow.Decision(w=5.5, h=4, S='YES').label('Hey, wait,\nthis flowchart\nis a trap!'))
    d += flow.Line().down(d.unit/4)
    d += flow.Wire('c', k=3.5, arrow='->').to(h.E)

# %% [markdown]
# ### Def: Span
# The set of all linear combinations of a list of vectors $v_1,...,v_m$ in $V$ is call the $\textbf{span}$ of $v_1,...,v_m$, denoted span($v_1,...,v_m$).  In other words,
#
# span($v_1,...,v_m$) $= \{a_1v_1+...+a_mv_m: a1,...,a_m \in \Bbb{F}\}$
#
# The span of the empty list $()$ is defined to be $\{0\}$.

# %% [markdown]
# ### Ex 3.2
#
# $\underbrace{(1,1,0),(0,0,1)}_{\text{a basis}} \in \{(x,x,y) \in \Bbb{F}^3: x,y\in \Bbb{F}$
#
# $(x,x,y)=x(1,1,0)+y(0,0,1)$
#
# $\alpha(1,1,0)+\beta(0,0,1)=0$
#
# $(\alpha,\alpha,\beta)=0 \iff \alpha=\beta=0$

# %% [markdown]
# ### Criterion
# $v_1,...,v_m$  is a basis of $V$ iff,
#
# $\forall v\in V, v=a_1v_1+...+a_nv_n$, where $a_1,...,a_m \in \Bbb{B}$
#
# FIXME!!! Finish this!

# %% [markdown]
# ### Appendix 1.  TBD
